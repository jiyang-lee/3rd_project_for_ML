# %% [markdown]
# # XAI4HEAT State Card Runtime Validation
#
# 상태카드 기반 외부 검증 산출물을 확인하는 재실행용 노트북입니다.

# %%
import pandas as pd
pd.set_option('display.max_columns', 80)

# %%
pd.read_csv('09_실험라인/state_card_external_validation/outputs/xai4heat_state_card_schema_mapping_audit.csv').groupby('match_status').size().reset_index(name='rows')
# Out:
#      match_status  rows
# 0         missing    10
# 1  semantic_match    30

# %%
pd.read_csv('09_실험라인/state_card_external_validation/outputs/xai4heat_state_card_runtime_outputs.csv')
# Out:
#                sample_id        data_scope substation_id  window_start  \
# 0  L12_combined_data.csv  XAI4HEAT_runtime           L12           NaN
# 1  L17_combined_data.csv  XAI4HEAT_runtime           L17           NaN
# 2  L22_combined_data.csv  XAI4HEAT_runtime           L22           NaN
# 3   L4_combined_data.csv  XAI4HEAT_runtime            L4           NaN
# 4   L8_combined_data.csv  XAI4HEAT_runtime            L8           NaN
#
#    window_end    primary_state  secondary_tags  fault_detected  task_detected  \
# 0         NaN  review_required             NaN           False          False
# 1         NaN  review_required             NaN           False          False
# 2         NaN  review_required             NaN           False          False
# 3         NaN  review_required             NaN           False          False
# 4         NaN  review_required             NaN           False          False
#
# ...
