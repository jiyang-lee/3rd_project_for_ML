# %% [markdown]
# # State Card External Validation Report
#
# 상태카드 기반 외부 검증 산출물을 확인하는 재실행용 노트북입니다.

# %%
import pandas as pd
pd.set_option('display.max_columns', 80)

# %%
pd.read_csv('09_실험라인/state_card_external_validation/outputs/state_card_external_validation_decision_matrix.csv')
# Out:
#                         decision_item                       status  \
# 0            state_card_schema_locked                         pass
# 1               m1_full_gate_internal                         pass
# 2  m1_m2_cross_manufacturer_pre_event                      partial
# 3         xai4heat_state_card_runtime  blocked_by_missing_features
# 4          xai4heat_label_performance               not_applicable
#
#                                             evidence  \
# 0                                   20 output fields
# 1  fault_gate_locked_for_runtime_v1_with_threshol...
# 2  LightGBM threshold 0.5 min_BA=0.7604, min_reca...
# 3  5/5 files review_required; feature availabilit...
# 4  XAI4HEAT has no fault/task/activity or report-...
#
#                                       final_decision
# 0  state_card_ready_internal_cross_manufacturer_p...
# 1  state_card_ready_internal_cross_manufacturer_p...
# 2  state_card_ready_internal_cross_manufacturer_p...
# ...

# %%
pd.read_csv('09_실험라인/state_card_external_validation/outputs/quality_audit.csv')
# Out:
#                                  check  pass  \
# 0  state_card_required_columns_present  True
# 1          non_fault_no_priority_score  True
# 2           m1_full_gate_rows_included  True
# 3          m1_m2_lightgbm_holdout_rows  True
# 4            xai4heat_no_label_metrics  True
# 5   xai4heat_missing_features_recorded  True
# 6        predist_original_not_modified  True
# 7       xai4heat_original_not_modified  True
#
#                                         evidence
# 0                                     missing=[]
# 1  priority score only populated on fault branch
# 2                                            179
# 3                                         rows=2
# 4        {'external_runtime_validation_only': 5}
# 5                          {True: 50, False: 15}
# 6                                          clean
# 7                                          clean
