# %% [markdown]
# # M1/M2 State Card Performance Validation
#
# 상태카드 기반 외부 검증 산출물을 확인하는 재실행용 노트북입니다.

# %%
import pandas as pd
pd.set_option('display.max_columns', 80)

# %%
pd.read_csv('09_실험라인/state_card_external_validation/outputs/m1_m2_state_card_metrics.csv')
# Out:
#   evaluation_scope feature_set              model  threshold  rows  \
# 0         M1_to_M2    common13    lightgbm_depth3        0.5    51
# 1         M2_to_M1    common13    lightgbm_depth3        0.5    61
# 2         M1_to_M2    common13     xgboost_depth3        0.4    51
# 3         M2_to_M1    common13     xgboost_depth3        0.4    61
# 4         M1_to_M2    common13  logistic_balanced        0.5    51
# 5         M2_to_M1    common13  logistic_balanced        0.5    61
#
#    normal_rows  pre_event_rows  balanced_accuracy  precision    recall  \
# 0           30              21           0.807143   0.833333  0.714286
# 1           35              26           0.760440   0.750000  0.692308
# 2           30              21           0.773810   0.750000  0.714286
# 3           35              26           0.746154   0.720000  0.692308
# 4           30              21           0.557143   0.454545  0.714286
# ...

# %%
pd.read_csv('09_실험라인/state_card_external_validation/outputs/state_card_all_outputs.csv').groupby(['data_scope','primary_state']).size().reset_index(name='rows')
# Out:
#               data_scope    primary_state  rows
# 0  M1_full_gate_internal         activity    47
# 1  M1_full_gate_internal            fault    56
# 2  M1_full_gate_internal           normal    34
# 3  M1_full_gate_internal             task    42
# 4               M1_to_M2            fault    18
# 5               M1_to_M2           normal    33
# 6               M2_to_M1            fault    24
# 7               M2_to_M1           normal    37
# 8       XAI4HEAT_runtime  review_required     5
