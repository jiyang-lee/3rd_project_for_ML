# %% [markdown]
# # Fault label x system x window audit
#
# 통합 스크립트가 만든 산출물을 읽어 결과를 확인하는 노트북입니다.

# %%
from pathlib import Path
import pandas as pd
out = Path('09_실험라인/m1_m2_system_fault_window_pre_event/outputs')
df = pd.read_csv(out / 'fault_label_system_window_audit.csv')
print(df.shape)
display(df.groupby(['manufacturer','label','window_policy']).size().head(30))
# Out:
# (285, 13)
# manufacturer  label      window_policy
# M1            normal     normal_event_7d    35
#               pre_event  report_pre_1d      29
#                          report_pre_3d      29
#                          report_pre_5d      29
#                          report_pre_7d      29
# M2            normal     normal_event_7d    30
#               pre_event  report_pre_1d      26
#                          report_pre_3d      26
#                          report_pre_5d      26
#                          report_pre_7d      26
# dtype: int64
