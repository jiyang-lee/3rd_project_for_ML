# %% [markdown]
# # Unified pre-event window model grid
#
# 통합 스크립트가 만든 산출물을 읽어 결과를 확인하는 노트북입니다.

# %%
from pathlib import Path
import pandas as pd
out = Path('09_실험라인/m1_m2_system_fault_window_pre_event/outputs')
df = pd.read_csv(out / 'unified_model_metrics.csv')
print(df.shape)
display(df.sort_values(['balanced_accuracy','recall'], ascending=False).head(20))
# Out:
# (648, 15)
#                                             dataset_id  \
# 3               all_systems__all_faults__report_pre_1d
# 4               all_systems__all_faults__report_pre_1d
# 5               all_systems__all_faults__report_pre_1d
# 6               all_systems__all_faults__report_pre_1d
# 7               all_systems__all_faults__report_pre_1d
# 8               all_systems__all_faults__report_pre_1d
# 12              all_systems__all_faults__report_pre_1d
# 13              all_systems__all_faults__report_pre_1d
# 14              all_systems__all_faults__report_pre_1d
# 15              all_systems__all_faults__report_pre_1d
# 16              all_systems__all_faults__report_pre_1d
# 17              all_systems__all_faults__report_pre_1d
# 85   all_systems__fault_control_controller__report_...
# 156  all_systems__fault_leakage_water_loss__report_...
# 157  all_systems__fault_leakage_water_loss__report_...
# 228  all_systems__fault_pressure_regulator__report_...
# 229  all_systems__fault_pressure_regulator__report_...
# 300     all_systems__fault_pump_failure__report_pre_1d
# 301     all_systems__fault_pump_failure__report_pre_1d
# 445      system_dhw_storage__all_faults__report_pre_1d
#
#                       model  threshold  rows  normal_rows  pre_event_rows  \
# 3    hist_gradient_boosting        0.4   113           65              48
# 4    hist_gradient_boosting        0.5   113           65              48
# 5    hist_gradient_boosting        0.6   113           65              48
# 6           lightgbm_depth3        0.4   113           65              48
# 7           lightgbm_depth3        0.5   113           65              48
# 8           lightgbm_depth3        0.6   113           65              48
# 12     random_forest_depth3        0.4   113           65              48
# 13     random_forest_depth3        0.5   113           65              48
# 14     random_forest_depth3        0.6   113           65              48
# 15           xgboost_depth3        0.4   113           65              48
# 16           xgboost_depth3        0.5   113           65              48
# 17           xgboost_depth3        0.6   113           65              48
# 85     random_forest_depth3        0.5    75           65              10
# 156    random_forest_depth3        0.4    74           65               9
# 157    random_forest_depth3        0.5    74           65               9
# 228    random_forest_depth3        0.4    73           65               8
# 229    random_forest_depth3        0.5    73           65               8
# 300    random_forest_depth3        0.4    75           65              10
# 301    random_forest_depth3        0.5    75           65              10
# 445    random_forest_depth3        0.5    61           34              27
#
#      balanced_accuracy  precision  recall   f1  normal_fpr  tn  fp  fn  tp
# 3                  1.0        1.0     1.0  1.0         0.0  65   0   0  48
# 4                  1.0        1.0     1.0  1.0         0.0  65   0   0  48
# 5                  1.0        1.0     1.0  1.0         0.0  65   0   0  48
# 6                  1.0        1.0     1.0  1.0         0.0  65   0   0  48
# 7                  1.0        1.0     1.0  1.0         0.0  65   0   0  48
# 8                  1.0        1.0     1.0  1.0         0.0  65   0   0  48
# 12                 1.0        1.0     1.0  1.0         0.0  65   0   0  48
# 13                 1.0        1.0     1.0  1.0         0.0  65   0   0  48
# 14                 1.0        1.0     1.0  1.0         0.0  65   0   0  48
# 15                 1.0        1.0     1.0  1.0         0.0  65   0   0  48
# 16                 1.0        1.0     1.0  1.0         0.0  65   0   0  48
# 17                 1.0        1.0     1.0  1.0         0.0  65   0   0  48
# 85                 1.0        1.0     1.0  1.0         0.0  65   0   0  10
# 156                1.0        1.0     1.0  1.0         0.0  65   0   0   9
# 157                1.0        1.0     1.0  1.0         0.0  65   0   0   9
# 228                1.0        1.0     1.0  1.0         0.0  65   0   0   8
# 229                1.0        1.0     1.0  1.0         0.0  65   0   0   8
# 300                1.0        1.0     1.0  1.0         0.0  65   0   0  10
# 301                1.0        1.0     1.0  1.0         0.0  65   0   0  10
# 445                1.0        1.0     1.0  1.0         0.0  34   0   0  27
