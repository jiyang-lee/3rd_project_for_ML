# %% [markdown]
# # Unified decision report
#
# 통합 스크립트가 만든 산출물을 읽어 결과를 확인하는 노트북입니다.

# %%
from pathlib import Path
import pandas as pd
out = Path('09_실험라인/m1_m2_system_fault_window_pre_event/outputs')
df = pd.read_csv(out / 'unified_decision_matrix.csv')
print(df.shape)
display(df.head(30))
# Out:
# (648, 11)
#                                            dataset_id                   model  \
# 0              all_systems__all_faults__report_pre_1d  hist_gradient_boosting
# 1              all_systems__all_faults__report_pre_1d  hist_gradient_boosting
# 2              all_systems__all_faults__report_pre_1d  hist_gradient_boosting
# 3              all_systems__all_faults__report_pre_1d         lightgbm_depth3
# 4              all_systems__all_faults__report_pre_1d         lightgbm_depth3
# 5              all_systems__all_faults__report_pre_1d         lightgbm_depth3
# 6              all_systems__all_faults__report_pre_1d    random_forest_depth3
# 7              all_systems__all_faults__report_pre_1d    random_forest_depth3
# 8              all_systems__all_faults__report_pre_1d    random_forest_depth3
# 9              all_systems__all_faults__report_pre_1d          xgboost_depth3
# 10             all_systems__all_faults__report_pre_1d          xgboost_depth3
# 11             all_systems__all_faults__report_pre_1d          xgboost_depth3
# 12  all_systems__fault_control_controller__report_...    random_forest_depth3
# 13  all_systems__fault_leakage_water_loss__report_...    random_forest_depth3
# 14  all_systems__fault_leakage_water_loss__report_...    random_forest_depth3
# 15  all_systems__fault_pressure_regulator__report_...    random_forest_depth3
# 16  all_systems__fault_pressure_regulator__report_...    random_forest_depth3
# 17     all_systems__fault_pump_failure__report_pre_1d    random_forest_depth3
# 18     all_systems__fault_pump_failure__report_pre_1d    random_forest_depth3
# 19      system_dhw_storage__all_faults__report_pre_1d    random_forest_depth3
# 20      system_dhw_storage__all_faults__report_pre_1d    random_forest_depth3
# 21  system_heating_common_only__all_faults__report...    random_forest_depth3
# 22  system_heating_common_only__all_faults__report...    random_forest_depth3
# 23  system_heating_common_only__all_faults__report...    random_forest_depth3
# 24  all_systems__fault_control_controller__report_...    random_forest_depth3
# 25   all_systems__fault_valve_actuator__report_pre_1d    random_forest_depth3
# 26  system_dhw_storage_return__all_faults__report_...    random_forest_depth3
# 27      system_dhw_storage__all_faults__report_pre_1d    random_forest_depth3
# 28      system_dhw_storage__all_faults__report_pre_1d          xgboost_depth3
# 29  all_systems__fault_control_controller__report_...  hist_gradient_boosting
#
#     threshold                       scope               fault_scope  \
# 0         0.4                 all_systems                all_faults
# 1         0.5                 all_systems                all_faults
# 2         0.6                 all_systems                all_faults
# 3         0.4                 all_systems                all_faults
# 4         0.5                 all_systems                all_faults
# 5         0.6                 all_systems                all_faults
# 6         0.4                 all_systems                all_faults
# 7         0.5                 all_systems                all_faults
# 8         0.6                 all_systems                all_faults
# 9         0.4                 all_systems                all_faults
# 10        0.5                 all_systems                all_faults
# 11        0.6                 all_systems                all_faults
# 12        0.5                 all_systems  fault_control_controller
# 13        0.4                 all_systems  fault_leakage_water_loss
# 14        0.5                 all_systems  fault_leakage_water_loss
# 15        0.4                 all_systems  fault_pressure_regulator
# 16        0.5                 all_systems  fault_pressure_regulator
# 17        0.4                 all_systems        fault_pump_failure
# 18        0.5                 all_systems        fault_pump_failure
# 19        0.5          system_dhw_storage                all_faults
# 20        0.6          system_dhw_storage                all_faults
# 21        0.4  system_heating_common_only                all_faults
# 22        0.5  system_heating_common_only                all_faults
# 23        0.6  system_heating_common_only                all_faults
# 24        0.4                 all_systems  fault_control_controller
# 25        0.4                 all_systems      fault_valve_actuator
# 26        0.5   system_dhw_storage_return                all_faults
# 27        0.4          system_dhw_storage                all_faults
# 28        0.5          system_dhw_storage                all_faults
# 29        0.4                 all_systems  fault_control_controller
#
#     window_policy  balanced_accuracy    recall  normal_fpr  candidate_pass  \
# 0   report_pre_1d           1.000000  1.000000    0.000000            True
# 1   report_pre_1d           1.000000  1.000000    0.000000            True
# 2   report_pre_1d           1.000000  1.000000    0.000000            True
# 3   report_pre_1d           1.000000  1.000000    0.000000            True
# 4   report_pre_1d           1.000000  1.000000    0.000000            True
# 5   report_pre_1d           1.000000  1.000000    0.000000            True
# 6   report_pre_1d           1.000000  1.000000    0.000000            True
# 7   report_pre_1d           1.000000  1.000000    0.000000            True
# 8   report_pre_1d           1.000000  1.000000    0.000000            True
# 9   report_pre_1d           1.000000  1.000000    0.000000            True
# 10  report_pre_1d           1.000000  1.000000    0.000000            True
# 11  report_pre_1d           1.000000  1.000000    0.000000            True
# 12  report_pre_1d           1.000000  1.000000    0.000000            True
# 13  report_pre_1d           1.000000  1.000000    0.000000            True
# 14  report_pre_1d           1.000000  1.000000    0.000000            True
# 15  report_pre_1d           1.000000  1.000000    0.000000            True
# 16  report_pre_1d           1.000000  1.000000    0.000000            True
# 17  report_pre_1d           1.000000  1.000000    0.000000            True
# 18  report_pre_1d           1.000000  1.000000    0.000000            True
# 19  report_pre_1d           1.000000  1.000000    0.000000            True
# 20  report_pre_1d           1.000000  1.000000    0.000000            True
# 21  report_pre_1d           1.000000  1.000000    0.000000            True
# 22  report_pre_1d           1.000000  1.000000    0.000000            True
# 23  report_pre_1d           1.000000  1.000000    0.000000            True
# 24  report_pre_1d           0.992308  1.000000    0.015385            True
# 25  report_pre_1d           0.992308  1.000000    0.015385            True
# 26  report_pre_1d           0.958333  1.000000    0.083333            True
# 27  report_pre_1d           0.955882  1.000000    0.088235            True
# 28  report_pre_1d           0.952070  0.962963    0.058824            True
# 29  report_pre_1d           0.950000  0.900000    0.000000            True
#
#                   decision
# 0   window_model_candidate
# 1   window_model_candidate
# 2   window_model_candidate
# 3   window_model_candidate
# 4   window_model_candidate
# 5   window_model_candidate
# 6   window_model_candidate
# 7   window_model_candidate
# 8   window_model_candidate
# 9   window_model_candidate
# 10  window_model_candidate
# 11  window_model_candidate
# 12  window_model_candidate
# 13  window_model_candidate
# 14  window_model_candidate
# 15  window_model_candidate
# 16  window_model_candidate
# 17  window_model_candidate
# 18  window_model_candidate
# 19  window_model_candidate
# 20  window_model_candidate
# 21  window_model_candidate
# 22  window_model_candidate
# 23  window_model_candidate
# 24  window_model_candidate
# 25  window_model_candidate
# 26  window_model_candidate
# 27  window_model_candidate
# 28  window_model_candidate
# 29  window_model_candidate
