# %% [markdown]
# # M1+M2 standard schema and system capability audit
#
# 이 노트북은 새 `09_실험라인` 산출물을 재현하기 위한 실행 단위입니다.

# %%
from pathlib import Path
import subprocess, sys
root = Path.cwd()
result = subprocess.run([sys.executable, str(root / 'scripts' / 'run_36_m1_m2_standard_pre_event.py'), '--stage', 'schema'], check=True, text=True, capture_output=True)
print(result.stdout)
if result.stderr:
    print(result.stderr)
# Out:
# schema/system audit complete
