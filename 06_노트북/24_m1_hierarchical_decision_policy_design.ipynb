# %% [markdown]
# # M1 Hierarchical Decision Policy Design
#
# Design a fault-first, context-augmented routing policy from steps 21-23.

# %% [markdown]
# ## Policy
# - Fault is the only predictive gate candidate.
# - Task is post-event context.
# - Activity is missingness-sensitive supporting context/candidate signal.

# %%
from pathlib import Path
import pandas as pd

ROOT = Path.cwd()
OUT = next(p for p in ROOT.iterdir() if p.is_dir() and p.name.startswith('07_'))
decision = pd.read_csv(OUT / 'm1_hierarchical_policy_decision_matrix.csv')
routing = pd.read_csv(OUT / 'm1_hierarchical_policy_event_routing.csv')
confusion = pd.read_csv(OUT / 'm1_hierarchical_policy_confusion_audit.csv')
decision
