# %% [markdown]
# # M1 Activity Predictive Gate Overlap Audit
#
# Validate whether `activity_pre_1d` is a lockable predictive signal or an overlap/missingness-sensitive candidate.

# %% [markdown]
# ## Inputs and Outputs
# Inputs reuse step 22 outputs and M1 window audits. Outputs are `m1_activity_predictive_gate_*` CSV files plus the 23 report.

# %%
from pathlib import Path
import pandas as pd

ROOT = Path.cwd()
OUT = next(p for p in ROOT.iterdir() if p.is_dir() and p.name.startswith('07_'))
metrics = pd.read_csv(OUT / 'm1_activity_predictive_gate_cv_metrics.csv')
decision = pd.read_csv(OUT / 'm1_activity_predictive_gate_decision_matrix.csv')
summary = pd.read_csv(OUT / 'm1_activity_predictive_gate_dataset_summary.csv')
decision
